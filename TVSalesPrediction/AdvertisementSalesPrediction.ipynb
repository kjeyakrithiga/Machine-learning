# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import pickle

# %%
dataset = pd.read_csv("../../Dataset/advertising.csv")
dataset
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
dataset.shape
dataset.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
x_points=np.array(dataset[['TV']])
y_points=np.array(dataset[['Sales']])

# %%
plt.plot(x_points,y_points,'o')
plt.show()

# %%
independent = dataset[['TV']]
dependent = dataset[['Sales']]

# %%
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
x_train,y_train,x_test,y_test
# Out:
# (        TV
#  131  265.2
#  96   197.6
#  181  218.5
#  19   147.3
#  153  171.3
#  ..     ...
#  67   139.3
#  192   17.2
#  117   76.4
#  47   239.9
#  172   19.6
#
#  [140 rows x 1 columns],
#       Sales
#  131   17.7
#  96    16.7
#  181   17.2
#  19    14.6
#  153   16.0
#  ..     ...
#  67    13.4
#  192    5.9
#  117    9.4
#  47    23.2
#  172    7.6
#
#  [140 rows x 1 columns],
#          TV
#  18    69.2
#  170   50.0
#  107   90.4
#  98   289.7
#  177  170.2
#  182   56.2
#  5      8.7
#  146  240.1
#  12    23.8
#  152  197.6
#  61   261.3
#  125   87.2
#  180  156.6
#  154  187.8
#  80    76.4
#  7    120.2
#  33   265.6
#  130    0.7
#  37    74.7
#  74   213.4
#  183  287.6
#  145  140.3
#  45   175.1
#  159  131.7
#  60    53.5
#  123  123.1
#  179  165.6
#  185  205.0
#  122  224.0
#  44    25.1
#  16    67.8
#  55   198.9
#  150  280.7
#  111  241.7
#  22    13.2
#  189   18.7
#  129   59.6
#  4    180.8
#  83    68.4
#  106   25.0
#  134   36.9
#  66    31.5
# ...

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
weight = regressor.coef_
weight
# Out:
# array([[0.05473199]])

# %%
bias = regressor.intercept_
bias
# Out:
# array([7.14382225])

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[10.93127621],
#        [ 9.88042193],
#        [12.09159447],
#        [22.99968079],
#        [16.45920756],
#        [10.21976029],
#        [ 7.6199906 ],
#        [20.28497391],
#        [ 8.4464437 ],
#        [17.95886418],
#        [21.44529217],
#        [11.91645209],
#        [15.71485245],
#        [17.42249065],
#        [11.32534656],
#        [13.72260788],
#        [21.68063975],
#        [ 7.18213465],
#        [11.23230217],
#        [18.82362968],
#        [22.88474361],
#        [14.82272095],
#        [16.72739433],
#        [14.35202581],
#        [10.07198391],
#        [13.88133066],
#        [16.20744039],
#        [18.36388094],
#        [19.40378881],
#        [ 8.51759529],
#        [10.85465142],
#        [18.03001578],
#        [22.50709285],
#        [20.3725451 ],
#        [ 7.86628457],
#        [ 8.16731053],
#        [10.40584907],
#        [17.03936669],
#        [10.88749061],
#        [ 8.51212209],
#        [ 9.16343282],
# ...

# %%
r_score=r2_score(y_pred,y_test)
r_score
# Out:
# 0.7575342873652274

# %%
salary_predition_model = pickle.dump(regressor,open("../../Models/TVSalesPrediction_SLR.sav",'wb'))

# %%
predict_model = pickle.load(open("../../Models/SalaryPrediction_SLR.sav",'rb'))
y_pred = predict_model.predict([[8]])
y_pred
# Out:
# C:\Users\prabh\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[100724.45550213]])
